# %%
import pandas as pd

results = pd.DataFrame({
    "Model":[
        "Logistic Regression",
        "Decision Tree",
        "Random Forest",
        "XGBoost"
    ],
    "Accuracy":[
        0.8034,
        0.7871,
        0.9092,
        0.90      # Replace with your corrected XGBoost accuracy
    ],
    "Precision":[
        0.6431,
        0.5907,
        0.8868,
        0.89
    ],
    "Recall":[
        0.5829,
        0.6444,
        0.7540,
        0.80
    ],
    "F1 Score":[
        0.6115,
        0.6164,
        0.8150,
        0.84
    ],
    "ROC AUC":[
        0.7330,
        0.7415,
        0.8596,
        0.90
    ]
})

results
# Out:
#                  Model  Accuracy  Precision  Recall  F1 Score  ROC AUC
# 0  Logistic Regression    0.8034     0.6431  0.5829    0.6115   0.7330
# 1        Decision Tree    0.7871     0.5907  0.6444    0.6164   0.7415
# 2        Random Forest    0.9092     0.8868  0.7540    0.8150   0.8596
# 3              XGBoost    0.9000     0.8900  0.8000    0.8400   0.9000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.bar(results["Model"], results["Accuracy"])
plt.title("Model Accuracy Comparison")
plt.ylabel("Accuracy")
plt.xticks(rotation=20)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.bar(results["Model"], results["ROC AUC"])
plt.title("ROC AUC Comparison")
plt.ylabel("ROC AUC")
plt.xticks(rotation=20)
plt.show()

# %%
results.to_csv("Model_Comparison.csv", index=False)

# %%
comparison.to_csv("Model_Comparison.csv", index=False)

print("CSV Saved Successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 comparison.to_csv("Model_Comparison.csv", index=False)
#       3 print("CSV Saved Successfully!")
#
# NameError: name 'comparison' is not defined
