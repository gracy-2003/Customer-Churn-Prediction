# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Display all columns
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("customer_churn_clean.csv")

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.tail()
# Out:
#       CustomerID  Count        Country       State          City  Zip_Code  \
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat_Long   Latitude   Longitude  Gender Senior_Citizen  \
# 7038  34.341737, -116.539416  34.341737 -116.539416  Female             No
# 7039  34.667815, -117.536183  34.667815 -117.536183    Male             No
# 7040  34.559882, -115.637164  34.559882 -115.637164  Female             No
# 7041     34.1678, -116.86433  34.167800 -116.864330  Female             No
# 7042  34.424926, -117.184503  34.424926 -117.184503    Male             No
#
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip_Code',
#        'Lat_Long', 'Latitude', 'Longitude', 'Gender', 'Senior_Citizen',
#        'Partner', 'Dependents', 'Tenure_Months', 'Phone_Service',
#        'Multiple_Lines', 'Internet_Service', 'Online_Security',
#        'Online_Backup', 'Device_Protection', 'Tech_Support', 'Streaming_TV',
#        'Streaming_Movies', 'Contract', 'Paperless_Billing', 'Payment_Method',
#        'Monthly_Charges', 'Total_Charges', 'Churn_Label', 'Churn_Value',
#        'Churn_Score', 'CLTV', 'Churn_Reason'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip_Code           7043 non-null   int64
#  6   Lat_Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior_Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure_Months      7043 non-null   int64
#  14  Phone_Service      7043 non-null   object
#  15  Multiple_Lines     7043 non-null   object
# ...

# %%
df.describe()
# Out:
#         Count      Zip_Code     Latitude    Longitude  Tenure_Months  \
# count  7043.0   7043.000000  7043.000000  7043.000000    7043.000000
# mean      1.0  93521.964646    36.282441  -119.798880      32.371149
# std       0.0   1865.794555     2.455723     2.157889      24.559481
# min       1.0  90001.000000    32.555828  -124.301372       0.000000
# 25%       1.0  92102.000000    34.030915  -121.815412       9.000000
# 50%       1.0  93552.000000    36.391777  -119.730885      29.000000
# 75%       1.0  95351.000000    38.224869  -118.043237      55.000000
# max       1.0  96161.000000    41.962127  -114.192901      72.000000
#
#        Monthly_Charges  Churn_Value  Churn_Score         CLTV
# count      7043.000000  7043.000000  7043.000000  7043.000000
# mean         64.761692     0.265370    58.699418  4400.295755
# std          30.090047     0.441561    21.525131  1183.057152
# min          18.250000     0.000000     5.000000  2003.000000
# ...

# %%
df.describe(include='object')
# Out:
#         CustomerID        Country       State         City  \
# count         7043           7043        7043         7043
# unique        7043              1           1         1129
# top     3668-QPYBK  United States  California  Los Angeles
# freq             1           7043        7043          305
#
#                       Lat_Long Gender Senior_Citizen Partner Dependents  \
# count                     7043   7043           7043    7043       7043
# unique                    1652      2              2       2          2
# top     33.964131, -118.272783   Male             No      No         No
# freq                         5   3555           5901    3641       5416
#
#        Phone_Service Multiple_Lines Internet_Service Online_Security  \
# count           7043           7043             7043            7043
# unique             2              3                3               3
# top              Yes             No      Fiber optic              No
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# Count                0
# Country              0
# State                0
# City                 0
# Zip_Code             0
# Lat_Long             0
# Latitude             0
# Longitude            0
# Gender               0
# Senior_Citizen       0
# Partner              0
# Dependents           0
# Tenure_Months        0
# Phone_Service        0
# Multiple_Lines       0
# Internet_Service     0
# Online_Security      0
# Online_Backup        0
# Device_Protection    0
# Tech_Support         0
# Streaming_TV         0
# Streaming_Movies     0
# Contract             0
# Paperless_Billing    0
# Payment_Method       0
# Monthly_Charges      0
# Total_Charges        0
# Churn_Label          0
# Churn_Value          0
# Churn_Score          0
# CLTV                 0
# Churn_Reason         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["CustomerID"].nunique()
# Out:
# 7043

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
(df["Gender"].value_counts(normalize=True)*100).round(2)
# Out:
# Gender
# Male      50.48
# Female    49.52
# Name: proportion, dtype: float64

# %%
gender = df["Gender"].value_counts()

plt.figure(figsize=(6,4))
plt.bar(gender.index, gender.values)
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Number of Customers")
plt.show()

# %%
df["Senior_Citizen"].value_counts()
# Out:
# Senior_Citizen
# No     5901
# Yes    1142
# Name: count, dtype: int64

# %%
senior = df["Senior_Citizen"].value_counts()

plt.figure(figsize=(6,4))
plt.bar(["No","Yes"], senior.values)
plt.title("Senior Citizen Distribution")
plt.xlabel("Senior Citizen")
plt.ylabel("Customers")
plt.show()

# %%
df["Partner"].value_counts()
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
partner = df["Partner"].value_counts()

plt.figure(figsize=(6,4))
plt.bar(partner.index, partner.values)
plt.title("Partner Distribution")
plt.xlabel("Partner")
plt.ylabel("Customers")
plt.show()

# %%
df["Dependents"].value_counts()
# Out:
# Dependents
# No     5416
# Yes    1627
# Name: count, dtype: int64

# %%
dependents = df["Dependents"].value_counts()

plt.figure(figsize=(6,4))
plt.bar(dependents.index, dependents.values)
plt.title("Dependents")
plt.xlabel("Dependents")
plt.ylabel("Customers")
plt.show()

# %%
df["Tenure_Months"].mean()
# Out:
# np.float64(32.37114865824223)

# %%
df["Tenure_Months"].min()
# Out:
# 0

# %%
df["Tenure_Months"].max()
# Out:
# 72

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Tenure_Months"], bins=20)
plt.title("Customer Tenure Distribution")
plt.xlabel("Tenure (Months)")
plt.ylabel("Customers")
plt.show()

# %%
df["Churn_Label"].value_counts()
# Out:
# Churn_Label
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
(df["Churn_Label"].value_counts(normalize=True)*100).round(2)
# Out:
# Churn_Label
# No     73.46
# Yes    26.54
# Name: proportion, dtype: float64

# %%
churn = df["Churn_Label"].value_counts()

plt.figure(figsize=(6,4))
plt.bar(churn.index, churn.values)
plt.title("Customer Churn")
plt.xlabel("Churn")
plt.ylabel("Customers")
plt.show()

# %%
pd.crosstab(df["Gender"], df["Churn_Label"])
# Out:
# Churn_Label    No  Yes
# Gender
# Female       2549  939
# Male         2625  930

# %%
gender_churn = pd.crosstab(df["Gender"], df["Churn_Label"])

gender_churn.plot(kind="bar", figsize=(7,5))

plt.title("Churn by Gender")
plt.xlabel("Gender")
plt.ylabel("Customers")
plt.show()

# %%
pd.crosstab(df["Senior_Citizen"], df["Churn_Label"])
# Out:
# Churn_Label       No   Yes
# Senior_Citizen
# No              4508  1393
# Yes              666   476

# %%
senior_churn = pd.crosstab(df["Senior_Citizen"], df["Churn_Label"])

senior_churn.plot(kind="bar", figsize=(7,5))

plt.title("Churn by Senior Citizen")
plt.xlabel("Senior Citizen")
plt.ylabel("Customers")
plt.show()

# %%
pd.crosstab(df["Partner"], df["Churn_Label"])
# Out:
# Churn_Label    No   Yes
# Partner
# No           2441  1200
# Yes          2733   669

# %%
partner_churn = pd.crosstab(df["Partner"], df["Churn_Label"])

partner_churn.plot(kind="bar", figsize=(7,5))

plt.title("Churn by Partner")
plt.xlabel("Partner")
plt.ylabel("Customers")
plt.show()

# %%
pd.crosstab(df["Dependents"], df["Churn_Label"])
# Out:
# Churn_Label    No   Yes
# Dependents
# No           3653  1763
# Yes          1521   106

# %%
dependent_churn = pd.crosstab(df["Dependents"], df["Churn_Label"])

dependent_churn.plot(kind="bar", figsize=(7,5))

plt.title("Churn by Dependents")
plt.xlabel("Dependents")
plt.ylabel("Customers")
plt.show()

# %%
print("Total Revenue :", round(df["Total_Charges"].sum(),2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 print("Total Revenue :", round(df["Total_Charges"].sum(),2))
#
# TypeError: type str doesn't define __round__ method

# %%
df["Total_Charges"].dtype
# Out:
# dtype('O')

# %%
df["Total_Charges"] = pd.to_numeric(df["Total_Charges"], errors="coerce")

# %%
df["Total_Charges"].dtype
# Out:
# dtype('float64')

# %%
df["Total_Charges"].isnull().sum()
# Out:
# np.int64(11)

# %%
df[df["Total_Charges"].isnull()][["CustomerID","Tenure_Months","Monthly_Charges","Total_Charges"]]
# Out:
#       CustomerID  Tenure_Months  Monthly_Charges  Total_Charges
# 2234  4472-LVYGI              0            52.55            NaN
# 2438  3115-CZMZD              0            20.25            NaN
# 2568  5709-LVOEQ              0            80.85            NaN
# 2667  4367-NUYAO              0            25.75            NaN
# 2856  1371-DWPAZ              0            56.05            NaN
# 4331  7644-OMVMY              0            19.85            NaN
# 4687  3213-VVOLG              0            25.35            NaN
# 5104  2520-SGTTA              0            20.00            NaN
# 5719  2923-ARZLG              0            19.70            NaN
# 6772  4075-WKNIU              0            73.35            NaN
# 6840  2775-SEFEE              0            61.90            NaN

# %%
df["Total_Charges"].isnull().sum()
# Out:
# np.int64(11)

# %%
df["Total_Charges"] = df["Total_Charges"].fillna(0)

# %%
df["Total_Charges"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Total_Charges"].dtype
# Out:
# dtype('float64')

# %%
print("Total Revenue :", round(df["Total_Charges"].sum(), 2))
# Out:
# Total Revenue : 16056168.7

# %%
print("Average Monthly Charges :", round(df["Monthly_Charges"].mean(),2))
# Out:
# Average Monthly Charges : 64.76

# %%
print("Average Total Charges :", round(df["Total_Charges"].mean(),2))
# Out:
# Average Total Charges : 2279.73

# %%
print(df["Monthly_Charges"].max())
# Out:
# 118.75

# %%
print(df["Monthly_Charges"].min())
# Out:
# 18.25

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Monthly_Charges"], bins=20)
plt.title("Monthly Charges Distribution")
plt.xlabel("Monthly Charges")
plt.ylabel("Customers")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Total_Charges"], bins=20)
plt.title("Total Charges Distribution")
plt.xlabel("Total Charges")
plt.ylabel("Customers")
plt.show()

# %%
revenue_contract = df.groupby("Contract")["Total_Charges"].sum()

print(revenue_contract)

plt.figure(figsize=(7,5))
plt.bar(revenue_contract.index,revenue_contract.values)
plt.title("Revenue by Contract")
plt.xlabel("Contract")
plt.ylabel("Revenue")
plt.show()
# Out:
# Contract
# Month-to-month    5305861.5
# One year          4467053.5
# Two year          6283253.7
# Name: Total_Charges, dtype: float64

# %%
payment_revenue=df.groupby("Payment_Method")["Total_Charges"].sum()

print(payment_revenue)

plt.figure(figsize=(10,5))
plt.bar(payment_revenue.index,payment_revenue.values)
plt.xticks(rotation=30)
plt.title("Revenue by Payment Method")
plt.ylabel("Revenue")
plt.show()
# Out:
# Payment_Method
# Bank transfer (automatic)    4748279.90
# Credit card (automatic)      4671593.35
# Electronic check             4944903.25
# Mailed check                 1691392.20
# Name: Total_Charges, dtype: float64

# %%
revenue_lost=df[df["Churn_Label"]=="Yes"]["Total_Charges"].sum()

print("Revenue Lost :",revenue_lost)
# Out:
# Revenue Lost : 2862926.9

# %%
df["Contract"].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
contract=df["Contract"].value_counts()

plt.figure(figsize=(7,5))
plt.bar(contract.index,contract.values)
plt.title("Contract Distribution")
plt.xlabel("Contract")
plt.ylabel("Customers")
plt.show()

# %%
contract_churn=pd.crosstab(df["Contract"],df["Churn_Label"])

contract_churn
# Out:
# Churn_Label       No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48

# %%
contract_churn.plot(kind="bar",figsize=(8,5))

plt.title("Churn by Contract")
plt.ylabel("Customers")
plt.show()

# %%
df.groupby("Contract")["Tenure_Months"].mean()
# Out:
# Contract
# Month-to-month    18.036645
# One year          42.044807
# Two year          56.735103
# Name: Tenure_Months, dtype: float64

# %%
df.groupby("Contract")["Monthly_Charges"].mean()
# Out:
# Contract
# Month-to-month    66.398490
# One year          65.048608
# Two year          60.770413
# Name: Monthly_Charges, dtype: float64

# %%
df["Internet_Service"].value_counts()
# Out:
# Internet_Service
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
internet=df["Internet_Service"].value_counts()

plt.figure(figsize=(7,5))
plt.bar(internet.index,internet.values)
plt.title("Internet Service Distribution")
plt.ylabel("Customers")
plt.show()

# %%
internet_churn=pd.crosstab(df["Internet_Service"],df["Churn_Label"])

internet_churn
# Out:
# Churn_Label         No   Yes
# Internet_Service
# DSL               1962   459
# Fiber optic       1799  1297
# No                1413   113

# %%
internet_churn.plot(kind="bar",figsize=(8,5))

plt.title("Churn by Internet Service")
plt.ylabel("Customers")
plt.show()

# %%
pd.crosstab(df["Phone_Service"],df["Churn_Label"])
# Out:
# Churn_Label      No   Yes
# Phone_Service
# No              512   170
# Yes            4662  1699

# %%
pd.crosstab(df["Multiple_Lines"],df["Churn_Label"])
# Out:
# Churn_Label         No  Yes
# Multiple_Lines
# No                2541  849
# No phone service   512  170
# Yes               2121  850

# %%
security=pd.crosstab(df["Online_Security"],df["Churn_Label"])

security
# Out:
# Churn_Label            No   Yes
# Online_Security
# No                   2037  1461
# No internet service  1413   113
# Yes                  1724   295

# %%
security.plot(kind="bar",figsize=(8,5))

plt.title("Online Security vs Churn")
plt.show()

# %%
backup=pd.crosstab(df["Online_Backup"],df["Churn_Label"])

backup.plot(kind="bar",figsize=(8,5))

plt.title("Online Backup vs Churn")
plt.show()

# %%
device=pd.crosstab(df["Device_Protection"],df["Churn_Label"])

device.plot(kind="bar",figsize=(8,5))

plt.title("Device Protection vs Churn")
plt.show()

# %%
tech=pd.crosstab(df["Tech_Support"],df["Churn_Label"])

tech.plot(kind="bar",figsize=(8,5))

plt.title("Tech Support vs Churn")
plt.show()

# %%
streamtv=pd.crosstab(df["Streaming_TV"],df["Churn_Label"])

streamtv.plot(kind="bar",figsize=(8,5))

plt.title("Streaming TV vs Churn")
plt.show()

# %%
streammovie=pd.crosstab(df["Streaming_Movies"],df["Churn_Label"])

streammovie.plot(kind="bar",figsize=(8,5))

plt.title("Streaming Movies vs Churn")
plt.show()

# %%
payment=df["Payment_Method"].value_counts()

payment
# Out:
# Payment_Method
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,5))

plt.bar(payment.index,payment.values)

plt.xticks(rotation=30)

plt.title("Payment Method Distribution")

plt.show()

# %%
payment_churn=pd.crosstab(df["Payment_Method"],df["Churn_Label"])

payment_churn
# Out:
# Churn_Label                  No   Yes
# Payment_Method
# Bank transfer (automatic)  1286   258
# Credit card (automatic)    1290   232
# Electronic check           1294  1071
# Mailed check               1304   308

# %%
payment_churn.plot(kind="bar",figsize=(10,5))

plt.title("Payment Method vs Churn")

plt.show()

# %%
state=df["State"].value_counts()

state.head(10)
# Out:
# State
# California    7043
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))

plt.bar(state.head(10).index,state.head(10).values)

plt.xticks(rotation=45)

plt.title("Top 10 States")

plt.show()

# %%
city=df["City"].value_counts()

city.head(10)
# Out:
# City
# Los Angeles      305
# San Diego        150
# San Jose         112
# Sacramento       108
# San Francisco    104
# Fresno            64
# Long Beach        60
# Oakland           52
# Stockton          44
# Bakersfield       40
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))

plt.bar(city.head(10).index,city.head(10).values)

plt.xticks(rotation=45)

plt.title("Top 10 Cities")

plt.show()

# %%
pd.crosstab(df["State"],df["Churn_Label"])
# Out:
# Churn_Label    No   Yes
# State
# California   5174  1869

# %%
df["CLTV"].describe()
# Out:
# count    7043.000000
# mean     4400.295755
# std      1183.057152
# min      2003.000000
# 25%      3469.000000
# 50%      4527.000000
# 75%      5380.500000
# max      6500.000000
# Name: CLTV, dtype: float64

# %%
print(df["CLTV"].mean())
# Out:
# 4400.295754650007

# %%
df.nlargest(10,"CLTV")[["CustomerID","CLTV","Monthly_Charges","Contract"]]
# Out:
#       CustomerID  CLTV  Monthly_Charges        Contract
# 3482  7622-FWGEW  6500            85.65        Two year
# 2550  6024-RUGGH  6499            25.20        Two year
# 6202  0383-CLDDA  6499            85.35        Two year
# 3600  2683-JXWQQ  6495            33.60  Month-to-month
# 3446  8894-JVDCV  6494           115.05        One year
# 6839  4114-QMKVN  6494            68.75        One year
# 3842  4531-AUZNK  6492            95.15        One year
# 4023  2181-TIDSV  6492            19.95        Two year
# 6411  1658-XUHBX  6492            88.75  Month-to-month
# 5964  0675-NCDYU  6491           116.40        Two year

# %%
plt.figure(figsize=(8,5))

plt.hist(df["CLTV"],bins=20)

plt.title("CLTV Distribution")

plt.xlabel("CLTV")

plt.ylabel("Customers")

plt.show()

# %%
cltv_churn=df.groupby("Churn_Label")["CLTV"].mean()

cltv_churn
# Out:
# Churn_Label
# No     4490.921337
# Yes    4149.414660
# Name: CLTV, dtype: float64

# %%
plt.figure(figsize=(6,4))

plt.bar(cltv_churn.index,cltv_churn.values)

plt.title("Average CLTV by Churn")

plt.ylabel("CLTV")

plt.show()

# %%
numeric_df=df.select_dtypes(include=["int64","float64"])

numeric_df.head()
# Out:
#    Count  Zip_Code   Latitude   Longitude  Tenure_Months  Monthly_Charges  \
# 0      1     90003  33.964131 -118.272783              2            53.85
# 1      1     90005  34.059281 -118.307420              2            70.70
# 2      1     90006  34.048013 -118.293953              8            99.65
# 3      1     90010  34.062125 -118.315709             28           104.80
# 4      1     90015  34.039224 -118.266293             49           103.70
#
#    Total_Charges  Churn_Value  Churn_Score  CLTV
# 0         108.15            1           86  3239
# 1         151.65            1           67  2701
# 2         820.50            1           86  5372
# 3        3046.05            1           84  5003
# 4        5036.30            1           89  5340

# %%
corr=numeric_df.corr()

corr
# Out:
#                  Count  Zip_Code  Latitude  Longitude  Tenure_Months  \
# Count              NaN       NaN       NaN        NaN            NaN
# Zip_Code           NaN  1.000000  0.895743  -0.784271       0.001041
# Latitude           NaN  0.895743  1.000000  -0.876779      -0.001631
# Longitude          NaN -0.784271 -0.876779   1.000000      -0.001678
# Tenure_Months      NaN  0.001041 -0.001631  -0.001678       1.000000
# Monthly_Charges    NaN -0.004596 -0.019899   0.024098       0.247900
# Total_Charges      NaN -0.000884 -0.009944   0.008876       0.826178
# Churn_Value        NaN  0.003346 -0.003384   0.004594      -0.352229
# Churn_Score        NaN -0.002769 -0.007684   0.004260      -0.224987
# CLTV               NaN -0.003562  0.000886   0.000485       0.396406
#
#                  Monthly_Charges  Total_Charges  Churn_Value  Churn_Score  \
# Count                        NaN            NaN          NaN          NaN
# ...

# %%
corr["Churn_Value"].sort_values(ascending=False)
# Out:
# Churn_Value        1.000000
# Churn_Score        0.664897
# Monthly_Charges    0.193356
# Longitude          0.004594
# Zip_Code           0.003346
# Latitude          -0.003384
# CLTV              -0.127463
# Total_Charges     -0.198324
# Tenure_Months     -0.352229
# Count                   NaN
# Name: Churn_Value, dtype: float64
